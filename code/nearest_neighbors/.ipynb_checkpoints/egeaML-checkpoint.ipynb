# %%
from egeaML import *
from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import confusion_matrix 
from sklearn.preprocessing import scale 
import pickle
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>                                                                                      │
# │                                                                                                  │
# │ ❱ 1 from egeaML import *                                                                         │
# │   2 from sklearn.model_selection import train_test_split, cross_val_score                        │
# │   3 from sklearn.neighbors import KNeighborsClassifier                                           │
# │   4 from sklearn.metrics import confusion_matrix                                                 │
# │                                                                                                  │
# │ /Users/dominikb1888/Library/CloudStorage/OneDrive-th-deg.de/Teaching/23S/KNBS/code/nearest_neigh │
# │ bors/egeaML.py:65 in <module>                                                                    │
# │                                                                                                  │
# │    62 from nltk.corpus import stopwords                                                          │
# │    63                                                                                            │
# │    64 #keras                                                                                     │
# │ ❱  65 from keras.models import Sequential                                                        │
# │    66 from keras.layers import Dense, Dropout, BatchNormalization, Activation                    │
# │    67 from keras.optimizers import Adam                                                          │
# │    68 from keras.callbacks import EarlyStopping                                                  │
# │                                                                                                  │
# │ /nix/store/xyblncxrp6spqpw8zhracgqx1d351j1v-python3.11-keras-2.11.0/lib/python3.11/site-packages │
# │ /keras/__init__.py:21 in <module>                                                                │
# │                                                                                                  │
# │   18 [keras.io](https://keras.io).                                                               │
# │   19 """                                                                                         │
# │   20 from keras import distribute                                                                │
# │ ❱ 21 from keras import models                                                                    │
# │   22 from keras.engine.input_layer import Input                                                  │
# │   23 from keras.engine.sequential import Sequential                                              │
# │   24 from keras.engine.training import Model                                                     │
# │                                                                                                  │
# │ /nix/store/xyblncxrp6spqpw8zhracgqx1d351j1v-python3.11-keras-2.11.0/lib/python3.11/site-packages │
# │ /keras/models/__init__.py:18 in <module>                                                         │
# │                                                                                                  │
# │   15 """Keras models API."""                                                                     │
# │   16                                                                                             │
# │   17                                                                                             │
# │ ❱ 18 from keras.engine.functional import Functional                                              │
# │   19 from keras.engine.sequential import Sequential                                              │
# │   20 from keras.engine.training import Model                                                     │
# │   21                                                                                             │
# │                                                                                                  │
# │ /nix/store/xyblncxrp6spqpw8zhracgqx1d351j1v-python3.11-keras-2.11.0/lib/python3.11/site-packages │
# │ /keras/engine/functional.py:24 in <module>                                                       │
# │                                                                                                  │
# │     21 import itertools                                                                          │
# │     22 import warnings                                                                           │
# │     23                                                                                           │
# │ ❱   24 import tensorflow.compat.v2 as tf                                                         │
# │     25                                                                                           │
# │     26 from keras import backend                                                                 │
# │     27 from keras.dtensor import layout_map as layout_map_lib                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
reader = DataIngestion(df='egeaML/data/data_intro.csv', col_target='male') 
data = reader.load_data() 
X = reader.features() 
y = reader.target()
